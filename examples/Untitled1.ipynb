# %%
#!/usr/bin/env python
"""Super-basic example, mainly for testing purposes.

This script trains a tiny network to compute square root. It also
serves as an example of using dumping.

"""
import logging
import math
import numpy
from argparse import ArgumentParser

import theano
from theano import tensor

from blocks.algorithms import GradientDescent, SteepestDescent
from blocks.bricks import MLP, Tanh, Identity
from blocks.bricks.cost import SquaredError
from blocks.initialization import IsotropicGaussian, Constant
from blocks.datasets import (ContainerDataset, BatchDataStream,
                             DataStreamMapping)
from blocks.datasets.schemes import ConstantScheme
from blocks.extensions import FinishAfter, Timing, Printing
from blocks.extensions.saveload import LoadFromDump, Dump
from blocks.extensions.monitoring import (TrainingDataMonitoring,
                                          DataStreamMonitoring)
from blocks.main_loop import MainLoop

floatX = theano.config.floatX


def get_data_stream(iterable):
    dataset = ContainerDataset({'numbers': iterable})
    data_stream = DataStreamMapping(dataset.get_default_stream(),
                                    lambda data: (math.sqrt(data[0]),),
                                    add_sources=('roots',))
    data_stream = DataStreamMapping(
        data_stream,
        lambda data: tuple((numpy.asarray(d, dtype=floatX) for d in data)))
    return BatchDataStream(data_stream, ConstantScheme(20))


def main(save_to, num_batches, continue_=False):
    mlp = MLP([Tanh(), Identity()], [1, 10, 1],
              weights_init=IsotropicGaussian(0.01),
              biases_init=Constant(0), seed=1)
    mlp.initialize()
    x = tensor.vector('numbers')
    y = tensor.vector('roots')
    cost = SquaredError().apply(y[:, None], mlp.apply(x[:, None]))
    cost.name = "cost"

    main_loop = MainLoop(
        mlp,
        get_data_stream(range(100)),
        GradientDescent(
            cost=cost, step_rule=SteepestDescent(learning_rate=0.001)),
        extensions=([LoadFromDump(save_to)] if continue_ else []) +
        [Timing(),
            FinishAfter(after_n_batches=num_batches),
            DataStreamMonitoring(
                [cost], get_data_stream(range(100, 200)),
                prefix="test"),
            TrainingDataMonitoring([cost], after_every_epoch=True),
            Dump(save_to),
            Printing()])
    main_loop.run()
    return main_loop

# %%
logging.basicConfig(level=logging.INFO)
parser = ArgumentParser("An example of learning to take square root")
parser.add_argument("--num-batches", type=int, default=1000,
                    help="Number of training batches to do.")
parser.add_argument("save_to", default="sqrt", nargs="?",
                    help=("Destination to save the state of the training "
                          "process."))
args = parser.parse_args()
main(**vars(args))

# %%
logging.basicConfig(level=logging.INFO)

# %%
main(save_to="sqrt", num_batches = 1000)
# Out:
# -------------------------------------------------------------------------------
# BEFORE FIRST EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 0
# 	 iterations_done: 0
# Log records from the iteration 0:
# 	 initialization_took: 0.436800003052
# 	 test_cost: 147.328491211
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 1
# 	 iterations_done: 5
# Log records from the iteration 5:
# 	 cost: 46.9838371277
# 	 epoch_took: 0.0055890083313
# 	 iteration_took: 0.000134944915771
# 	 test_cost: 135.907363892
# 	 total_took: 0.442317962646
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 2
# 	 iterations_done: 10
# Log records from the iteration 10:
# 	 cost: 40.5924301147
# 	 epoch_took: 0.00287580490112
# 	 iteration_took: 0.000134944915771
# 	 test_cost: 122.701049805
# 	 total_took: 0.447926998138
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 3
# 	 iterations_done: 15
# Log records from the iteration 15:
# 	 cost: 34.0402336121
# 	 epoch_took: 0.00275707244873
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 110.645309448
# 	 total_took: 0.45343208313
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 4
# 	 iterations_done: 20
# Log records from the iteration 20:
# 	 cost: 28.4038734436
# 	 epoch_took: 0.00276708602905
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 100.044540405
# 	 total_took: 0.458908081055
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 5
# 	 iterations_done: 25
# Log records from the iteration 25:
# 	 cost: 23.7202568054
# 	 epoch_took: 0.00280499458313
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 90.8241348267
# 	 total_took: 0.464401960373
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 6
# 	 iterations_done: 30
# Log records from the iteration 30:
# 	 cost: 19.8702793121
# 	 epoch_took: 0.00275111198425
# 	 iteration_took: 0.000131130218506
# 	 test_cost: 82.8304214478
# 	 total_took: 0.469868898392
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 7
# 	 iterations_done: 35
# Log records from the iteration 35:
# 	 cost: 16.7212791443
# 	 epoch_took: 0.00277996063232
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 75.9030380249
# 	 total_took: 0.47535610199
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 8
# 	 iterations_done: 40
# Log records from the iteration 40:
# 	 cost: 14.1522703171
# 	 epoch_took: 0.00276398658752
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 69.8941421509
# 	 total_took: 0.480844974518
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 9
# 	 iterations_done: 45
# Log records from the iteration 45:
# 	 cost: 12.0588636398
# 	 epoch_took: 0.00278401374817
# 	 iteration_took: 0.000136852264404
# 	 test_cost: 64.6731338501
# 	 total_took: 0.486377000809
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 10
# 	 iterations_done: 50
# Log records from the iteration 50:
# 	 cost: 10.3531446457
# 	 epoch_took: 0.00277805328369
# 	 iteration_took: 0.000131845474243
# 	 test_cost: 60.1268501282
# 	 total_took: 0.491900920868
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 11
# 	 iterations_done: 55
# Log records from the iteration 55:
# 	 cost: 8.96198940277
# 	 epoch_took: 0.00468301773071
# 	 iteration_took: 0.000223875045776
# 	 test_cost: 56.1580581665
# 	 total_took: 0.499691009521
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 12
# 	 iterations_done: 60
# Log records from the iteration 60:
# 	 cost: 7.82498168945
# 	 epoch_took: 0.00505208969116
# 	 iteration_took: 0.000230073928833
# 	 test_cost: 52.6835327148
# 	 total_took: 0.50975394249
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 13
# 	 iterations_done: 65
# Log records from the iteration 65:
# 	 cost: 6.89236354828
# 	 epoch_took: 0.00284218788147
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 49.6319999695
# 	 total_took: 0.517327070236
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 14
# 	 iterations_done: 70
# Log records from the iteration 70:
# 	 cost: 6.12317180634
# 	 epoch_took: 0.00289797782898
# 	 iteration_took: 0.000164985656738
# 	 test_cost: 46.9424057007
# 	 total_took: 0.522969961166
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 15
# 	 iterations_done: 75
# Log records from the iteration 75:
# 	 cost: 5.48363256454
# 	 epoch_took: 0.00297093391418
# 	 iteration_took: 0.000138998031616
# 	 test_cost: 44.5620918274
# 	 total_took: 0.529309988022
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 16
# 	 iterations_done: 80
# Log records from the iteration 80:
# 	 cost: 4.94577884674
# 	 epoch_took: 0.00291705131531
# 	 iteration_took: 0.000136137008667
# 	 test_cost: 42.4454231262
# 	 total_took: 0.535140991211
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 17
# 	 iterations_done: 85
# Log records from the iteration 85:
# 	 cost: 4.48633289337
# 	 epoch_took: 0.00279498100281
# 	 iteration_took: 0.000135898590088
# 	 test_cost: 40.5523147583
# 	 total_took: 0.540662050247
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 18
# 	 iterations_done: 90
# Log records from the iteration 90:
# 	 cost: 4.08587789536
# 	 epoch_took: 0.00282001495361
# 	 iteration_took: 0.000137090682983
# 	 test_cost: 38.8471031189
# 	 total_took: 0.546365976334
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 19
# 	 iterations_done: 95
# Log records from the iteration 95:
# 	 cost: 3.72848582268
# 	 epoch_took: 0.00470304489136
# 	 iteration_took: 0.000235080718994
# 	 test_cost: 37.2974472046
# 	 total_took: 0.554177045822
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 20
# 	 iterations_done: 100
# Log records from the iteration 100:
# 	 cost: 3.40210008621
# 	 epoch_took: 0.00376987457275
# 	 iteration_took: 0.000136137008667
# 	 test_cost: 35.8736877441
# 	 total_took: 0.563020944595
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 21
# 	 iterations_done: 105
# Log records from the iteration 105:
# 	 cost: 3.09994387627
# 	 epoch_took: 0.0028018951416
# 	 iteration_took: 0.000131130218506
# 	 test_cost: 34.5491409302
# 	 total_took: 0.568610906601
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 22
# 	 iterations_done: 110
# Log records from the iteration 110:
# 	 cost: 2.82197833061
# 	 epoch_took: 0.00290203094482
# 	 iteration_took: 0.000131845474243
# 	 test_cost: 33.3025779724
# 	 total_took: 0.575721025467
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 23
# 	 iterations_done: 115
# Log records from the iteration 115:
# 	 cost: 2.5727417469
# 	 epoch_took: 0.00275301933289
# 	 iteration_took: 0.000131130218506
# 	 test_cost: 32.1227035522
# 	 total_took: 0.581219911575
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 24
# 	 iterations_done: 120
# Log records from the iteration 120:
# 	 cost: 2.35458183289
# 	 epoch_took: 0.0027859210968
# 	 iteration_took: 0.000134944915771
# 	 test_cost: 31.0090675354
# 	 total_took: 0.586795091629
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 25
# 	 iterations_done: 125
# Log records from the iteration 125:
# 	 cost: 2.16461753845
# 	 epoch_took: 0.00280404090881
# 	 iteration_took: 0.000134944915771
# 	 test_cost: 29.9649047852
# 	 total_took: 0.592466115952
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 26
# 	 iterations_done: 130
# Log records from the iteration 130:
# 	 cost: 1.99808049202
# 	 epoch_took: 0.00275707244873
# 	 iteration_took: 0.000131130218506
# 	 test_cost: 28.9901180267
# 	 total_took: 0.597944974899
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 27
# 	 iterations_done: 135
# Log records from the iteration 135:
# 	 cost: 1.85095405579
# 	 epoch_took: 0.00466799736023
# 	 iteration_took: 0.000218152999878
# 	 test_cost: 28.0809669495
# 	 total_took: 0.605751991272
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 28
# 	 iterations_done: 140
# Log records from the iteration 140:
# 	 cost: 1.72024214268
# 	 epoch_took: 0.00494909286499
# 	 iteration_took: 0.000152826309204
# 	 test_cost: 27.2322597504
# 	 total_took: 0.615691900253
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 29
# 	 iterations_done: 145
# Log records from the iteration 145:
# 	 cost: 1.60361099243
# 	 epoch_took: 0.00278687477112
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 26.4387397766
# 	 total_took: 0.621309041977
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 30
# 	 iterations_done: 150
# Log records from the iteration 150:
# 	 cost: 1.49911832809
# 	 epoch_took: 0.00410890579224
# 	 iteration_took: 0.000136137008667
# 	 test_cost: 25.695476532
# 	 total_took: 0.628433942795
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 31
# 	 iterations_done: 155
# Log records from the iteration 155:
# 	 cost: 1.4051015377
# 	 epoch_took: 0.00283813476562
# 	 iteration_took: 0.000147104263306
# 	 test_cost: 24.9980201721
# 	 total_took: 0.634146928787
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 32
# 	 iterations_done: 160
# Log records from the iteration 160:
# 	 cost: 1.3201392889
# 	 epoch_took: 0.00277590751648
# 	 iteration_took: 0.000131130218506
# 	 test_cost: 24.3423709869
# 	 total_took: 0.639626979828
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 33
# 	 iterations_done: 165
# Log records from the iteration 165:
# 	 cost: 1.2430267334
# 	 epoch_took: 0.00276303291321
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 23.7249965668
# 	 total_took: 0.645260095596
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 34
# 	 iterations_done: 170
# Log records from the iteration 170:
# 	 cost: 1.17277026176
# 	 epoch_took: 0.00281810760498
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 23.1428451538
# 	 total_took: 0.650882959366
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 35
# 	 iterations_done: 175
# Log records from the iteration 175:
# 	 cost: 1.10859167576
# 	 epoch_took: 0.00464606285095
# 	 iteration_took: 0.000223159790039
# 	 test_cost: 22.5932788849
# 	 total_took: 0.658629894257
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 36
# 	 iterations_done: 180
# Log records from the iteration 180:
# 	 cost: 1.04995393753
# 	 epoch_took: 0.00507307052612
# 	 iteration_took: 0.000236034393311
# 	 test_cost: 22.0741004944
# 	 total_took: 0.668700933456
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 37
# 	 iterations_done: 185
# Log records from the iteration 185:
# 	 cost: 0.996585845947
# 	 epoch_took: 0.00285410881042
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 21.5835075378
# 	 total_took: 0.676248073578
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 38
# 	 iterations_done: 190
# Log records from the iteration 190:
# 	 cost: 0.948506653309
# 	 epoch_took: 0.00279092788696
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 21.1200904846
# 	 total_took: 0.681811094284
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 39
# 	 iterations_done: 195
# Log records from the iteration 195:
# 	 cost: 0.906041324139
# 	 epoch_took: 0.0028920173645
# 	 iteration_took: 0.000169038772583
# 	 test_cost: 20.6828117371
# 	 total_took: 0.687472105026
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 40
# 	 iterations_done: 200
# Log records from the iteration 200:
# 	 cost: 0.869823455811
# 	 epoch_took: 0.00292491912842
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 20.2709999084
# 	 total_took: 0.695229053497
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 41
# 	 iterations_done: 205
# Log records from the iteration 205:
#  cost: 0.840785801411
# 	 epoch_took: 0.00296187400818
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 19.8843421936
# 	 total_took: 0.701023101807
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 42
# 	 iterations_done: 210
# Log records from the iteration 210:
# 	 cost: 0.820105552673
# 	 epoch_took: 0.00313997268677
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 19.5229034424
# 	 total_took: 0.70747089386
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 43
# 	 iterations_done: 215
# Log records from the iteration 215:
# 	 cost: 0.809033036232
# 	 epoch_took: 0.00276589393616
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 19.187046051
# 	 total_took: 0.713066101074
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 44
# 	 iterations_done: 220
# Log records from the iteration 220:
# 	 cost: 0.808471560478
# 	 epoch_took: 0.00283789634705
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 18.877368927
# 	 total_took: 0.718732118607
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 45
# 	 iterations_done: 225
# Log records from the iteration 225:
# 	 cost: 0.818224549294
# 	 epoch_took: 0.00333404541016
# 	 iteration_took: 0.000239133834839
# 	 test_cost: 18.5943698883
# 	 total_took: 0.724745035172
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 46
# 	 iterations_done: 230
# Log records from the iteration 230:
# 	 cost: 0.836237251759
# 	 epoch_took: 0.00293016433716
# 	 iteration_took: 0.000131845474243
# 	 test_cost: 18.337928772
# 	 total_took: 0.731446027756
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 47
# 	 iterations_done: 235
# Log records from the iteration 235:
# 	 cost: 0.858870863914
# 	 epoch_took: 0.00277709960938
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 18.1068115234
# 	 total_took: 0.73702788353
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 48
# 	 iterations_done: 240
# Log records from the iteration 240:
# 	 cost: 0.882763743401
# 	 epoch_took: 0.00277805328369
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 17.8988838196
# 	 total_took: 0.742541074753
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 49
# 	 iterations_done: 245
# Log records from the iteration 245:
# 	 cost: 0.906207382679
# 	 epoch_took: 0.00280809402466
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 17.7117958069
# 	 total_took: 0.748220920563
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 50
# 	 iterations_done: 250
# Log records from the iteration 250:
# 	 cost: 0.92840641737
# 	 epoch_took: 0.00276589393616
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 17.5433082581
# 	 total_took: 0.753771066666
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 51
# 	 iterations_done: 255
# Log records from the iteration 255:
# 	 cost: 0.949057221413
# 	 epoch_took: 0.00281715393066
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 17.3914070129
# 	 total_took: 0.759741067886
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 52
# 	 iterations_done: 260
# Log records from the iteration 260:
# 	 cost: 0.968032538891
# 	 epoch_took: 0.00277709960938
# 	 iteration_took: 0.00013279914856
# 	 test_cost: 17.2542667389
# 	 total_took: 0.765285015106
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 53
# 	 iterations_done: 265
# Log records from the iteration 265:
# 	 cost: 0.985384583473
# 	 epoch_took: 0.0028121471405
# 	 iteration_took: 0.000134944915771
# 	 test_cost: 17.1303005219
# 	 total_took: 0.770915031433
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 54
# 	 iterations_done: 270
# Log records from the iteration 270:
# 	 cost: 1.00107681751
# 	 epoch_took: 0.00279402732849
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 17.0180473328
# 	 total_took: 0.776458024979
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 55
# 	 iterations_done: 275
# Log records from the iteration 275:
# 	 cost: 1.01540565491
# 	 epoch_took: 0.00300407409668
# 	 iteration_took: 0.000135898590088
# 	 test_cost: 16.9163837433
# 	 total_took: 0.783523082733
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 56
# 	 iterations_done: 280
# Log records from the iteration 280:
# 	 cost: 1.0279610157
# 	 epoch_took: 0.00276303291321
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 16.8238811493
# 	 total_took: 0.789078950882
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 57
# 	 iterations_done: 285
# Log records from the iteration 285:
# 	 cost: 1.04014766216
# 	 epoch_took: 0.00281310081482
# 	 iteration_took: 0.000135183334351
# 	 test_cost: 16.7404060364
# 	 total_took: 0.794621944427
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 58
# 	 iterations_done: 290
# Log records from the iteration 290:
# 	 cost: 1.04849362373
# 	 epoch_took: 0.00295495986938
# 	 iteration_took: 0.000134944915771
# 	 test_cost: 16.6626529694
# 	 total_took: 0.800319910049
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 59
# 	 iterations_done: 295
# Log records from the iteration 295:
# 	 cost: 1.06352066994
# 	 epoch_took: 0.00278282165527
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 16.5972042084
# 	 total_took: 0.805867910385
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 60
# 	 iterations_done: 300
# Log records from the iteration 300:
# 	 cost: 1.05455219746
# 	 epoch_took: 0.00281596183777
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 16.5204029083
# 	 total_took: 0.811861038208
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 61
# 	 iterations_done: 305
# Log records from the iteration 305:
# 	 cost: 1.12780404091
# 	 epoch_took: 0.00284481048584
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 16.5062503815
# 	 total_took: 0.817481994629
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 62
# 	 iterations_done: 310
# Log records from the iteration 310:
# 	 cost: 0.956312179565
# 	 epoch_took: 0.00278091430664
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 16.3349494934
# 	 total_took: 0.823002099991
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 63
# 	 iterations_done: 315
# Log records from the iteration 315:
# 	 cost: 2.28936290741
# 	 epoch_took: 0.00287699699402
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 16.5171813965
# 	 total_took: 0.828610897064
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 64
# 	 iterations_done: 320
# Log records from the iteration 320:
# 	 cost: 2.91434073448
# 	 epoch_took: 0.00437998771667
# 	 iteration_took: 0.000160932540894
# 	 test_cost: 16.3280849457
# 	 total_took: 0.835751056671
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 65
# 	 iterations_done: 325
# Log records from the iteration 325:
# 	 cost: 5.70292711258
# 	 epoch_took: 0.00279402732849
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 19.4293365479
# 	 total_took: 0.841378927231
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 66
# 	 iterations_done: 330
# Log records from the iteration 330:
# 	 cost: 4.1803445816
# 	 epoch_took: 0.0027801990509
# 	 iteration_took: 0.000130891799927
# 	 test_cost: 29.5168762207
# 	 total_took: 0.846879005432
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 67
# 	 iterations_done: 335
# Log records from the iteration 335:
# 	 cost: 3.37110066414
# 	 epoch_took: 0.00294089317322
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 29.1331634521
# 	 total_took: 0.852556943893
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 68
# 	 iterations_done: 340
# Log records from the iteration 340:
# 	 cost: 3.24236369133
# 	 epoch_took: 0.00276923179626
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 28.390422821
# 	 total_took: 0.858047962189
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 69
# 	 iterations_done: 345
# Log records from the iteration 345:
# 	 cost: 3.1625521183
# 	 epoch_took: 0.00289106369019
# 	 iteration_took: 0.000135183334351
# 	 test_cost: 28.0879573822
# 	 total_took: 0.86406993866
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 70
# 	 iterations_done: 350
# Log records from the iteration 350:
# 	 cost: 2.99695181847
# 	 epoch_took: 0.00278401374817
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 27.4701290131
# 	 total_took: 0.869764089584
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 71
# 	 iterations_done: 355
# Log records from the iteration 355:
# 	 cost: 2.78033852577
# 	 epoch_took: 0.00278806686401
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 26.7982292175
# 	 total_took: 0.875401973724
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 72
# 	 iterations_done: 360
# Log records from the iteration 360:
# 	 cost: 3.27897000313
# 	 epoch_took: 0.00281405448914
# 	 iteration_took: 0.000131130218506
# 	 test_cost: 26.7365818024
# 	 total_took: 0.880965948105
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 73
# 	 iterations_done: 365
# Log records from the iteration 365:
# 	 cost: 4.23486709595
# 	 epoch_took: 0.00282692909241
# 	 iteration_took: 0.000138998031616
# 	 test_cost: 26.0494537354
# 	 total_took: 0.886598110199
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 74
# 	 iterations_done: 370
# Log records from the iteration 370:
# 	 cost: 3.07007336617
# 	 epoch_took: 0.00283002853394
# 	 iteration_took: 0.000131845474243
# 	 test_cost: 26.0293178558
# 	 total_took: 0.893028020859
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 75
# 	 iterations_done: 375
# Log records from the iteration 375:
# 	 cost: 2.88282871246
# 	 epoch_took: 0.00279188156128
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 25.5566272736
# 	 total_took: 0.898569107056
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 76
# 	 iterations_done: 380
# Log records from the iteration 380:
# 	 cost: 2.63605523109
# 	 epoch_took: 0.00282311439514
# 	 iteration_took: 0.000131845474243
# 	 test_cost: 25.1487026215
# 	 total_took: 0.904123067856
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 77
# 	 iterations_done: 385
# Log records from the iteration 385:
# 	 cost: 2.58628797531
# 	 epoch_took: 0.00278496742249
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 24.8304233551
# 	 total_took: 0.909797906876
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 78
# 	 iterations_done: 390
# Log records from the iteration 390:
# 	 cost: 2.25806546211
# 	 epoch_took: 0.00289297103882
# 	 iteration_took: 0.000160932540894
# 	 test_cost: 24.3356227875
# 	 total_took: 0.915818929672
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 79
# 	 iterations_done: 395
# Log records from the iteration 395:
# 	 cost: 2.73857116699
# 	 epoch_took: 0.00276708602905
# 	 iteration_took: 0.000130891799927
# 	 test_cost: 24.12890625
# 	 total_took: 0.921396017075
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 80
# 	 iterations_done: 400
# Log records from the iteration 400:
# 	 cost: 2.8725001812
# 	 epoch_took: 0.00278496742249
# 	 iteration_took: 0.000134944915771
# 	 test_cost: 23.6804237366
# 	 total_took: 0.92689704895
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 81
# 	 iterations_done: 405
# Log records from the iteration 405:
# 	 cost: 2.60865974426
# 	 epoch_took: 0.00281000137329
# 	 iteration_took: 0.000149011611938
# 	 test_cost: 23.5377292633
# 	 total_took: 0.932456016541
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 82
# 	 iterations_done: 410
# Log records from the iteration 410:
# 	 cost: 2.48405957222
# 	 epoch_took: 0.00275683403015
# 	 iteration_took: 0.000130891799927
# 	 test_cost: 23.1334552765
# 	 total_took: 0.937982082367
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 83
# 	 iterations_done: 415
# Log records from the iteration 415:
# 	 cost: 2.54357528687
# 	 epoch_took: 0.00322318077087
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 22.7212581635
# 	 total_took: 0.945401906967
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 84
# 	 iterations_done: 420
# Log records from the iteration 420:
# 	 cost: 3.4920334816
# 	 epoch_took: 0.00289106369019
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 23.0772609711
# 	 total_took: 0.951078891754
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 85
# 	 iterations_done: 425
# Log records from the iteration 425:
# 	 cost: 5.85854434967
# 	 epoch_took: 0.00277018547058
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 39.783203125
# 	 total_took: 0.956521987915
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 86
# 	 iterations_done: 430
# Log records from the iteration 430:
# 	 cost: 4.54316425323
# 	 epoch_took: 0.00279307365417
# 	 iteration_took: 0.000134944915771
# 	 test_cost: 38.4101524353
# 	 total_took: 0.962363004684
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 87
# 	 iterations_done: 435
# Log records from the iteration 435:
# 	 cost: 4.12819433212
# 	 epoch_took: 0.00290608406067
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 37.1130485535
# 	 total_took: 0.968368053436
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 88
# 	 iterations_done: 440
# Log records from the iteration 440:
# 	 cost: 3.80651330948
# 	 epoch_took: 0.00276803970337
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 35.8201675415
# 	 total_took: 0.973889112473
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 89
# 	 iterations_done: 445
# Log records from the iteration 445:
# 	 cost: 3.57434988022
# 	 epoch_took: 0.00276803970337
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 34.7411499023
# 	 total_took: 0.97936296463
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 90
# 	 iterations_done: 450
# Log records from the iteration 450:
# 	 cost: 3.30205154419
# 	 epoch_took: 0.0028190612793
# 	 iteration_took: 0.000135183334351
# 	 test_cost: 33.5967407227
# 	 total_took: 0.984884977341
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 91
# 	 iterations_done: 455
# Log records from the iteration 455:
# 	 cost: 3.09571647644
# 	 epoch_took: 0.00279903411865
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 32.6650009155
# 	 total_took: 0.990463018417
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 92
# 	 iterations_done: 460
# Log records from the iteration 460:
# 	 cost: 2.78671741486
# 	 epoch_took: 0.00426197052002
# 	 iteration_took: 0.000140905380249
# 	 test_cost: 31.6089229584
# 	 total_took: 0.997437000275
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 93
# 	 iterations_done: 465
# Log records from the iteration 465:
# 	 cost: 2.64676976204
# 	 epoch_took: 0.0027859210968
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 30.6640968323
# 	 total_took: 1.00309491158
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 94
# 	 iterations_done: 470
# Log records from the iteration 470:
# 	 cost: 2.47842288017
# 	 epoch_took: 0.00277900695801
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 29.8283882141
# 	 total_took: 1.00854897499
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 95
# 	 iterations_done: 475
# Log records from the iteration 475:
# 	 cost: 2.26993608475
# 	 epoch_took: 0.00284504890442
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 28.9195365906
# 	 total_took: 1.01409697533
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 96
# 	 iterations_done: 480
# Log records from the iteration 480:
# 	 cost: 2.23762083054
# 	 epoch_took: 0.00286102294922
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 28.2738399506
# 	 total_took: 1.02022409439
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 97
# 	 iterations_done: 485
# Log records from the iteration 485:
# 	 cost: 1.90209579468
# 	 epoch_took: 0.00296092033386
# 	 iteration_took: 0.000152111053467
# 	 test_cost: 27.4549922943
# 	 total_took: 1.02597403526
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 98
# 	 iterations_done: 490
# Log records from the iteration 490:
# 	 cost: 1.77617108822
# 	 epoch_took: 0.00299096107483
# 	 iteration_took: 0.000209808349609
# 	 test_cost: 26.7394657135
# 	 total_took: 1.03171491623
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 99
# 	 iterations_done: 495
# Log records from the iteration 495:
# 	 cost: 1.58663725853
# 	 epoch_took: 0.00276708602905
# 	 iteration_took: 0.00013279914856
# 	 test_cost: 25.9816226959
# 	 total_took: 1.03728795052
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 100
# 	 iterations_done: 500
# Log records from the iteration 500:
# 	 cost: 1.49553012848
# 	 epoch_took: 0.00282287597656
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 25.2722969055
# 	 total_took: 1.04325890541
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 101
# 	 iterations_done: 505
# Log records from the iteration 505:
# 	 cost: 1.42222630978
# 	 epoch_took: 0.00412106513977
# 	 iteration_took: 0.000219821929932
# 	 test_cost: 24.6095199585
# 	 total_took: 1.05004405975
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 102
# 	 iterations_done: 510
# Log records from the iteration 510:
# 	 cost: 1.37306761742
# 	 epoch_took: 0.00295805931091
# 	 iteration_took: 0.0001380443573
# 	 test_cost: 23.9976654053
# 	 total_took: 1.0561439991
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 103
# 	 iterations_done: 515
# Log records from the iteration 515:
# 	 cost: 1.34709191322
# 	 epoch_took: 0.0027539730072
# 	 iteration_took: 0.000130891799927
# 	 test_cost: 23.4396343231
# 	 total_took: 1.06164503098
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 104
# 	 iterations_done: 520
# Log records from the iteration 520:
# 	 cost: 1.3382819891
# 	 epoch_took: 0.00300192832947
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 22.9372501373
# 	 total_took: 1.06754589081
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 105
# 	 iterations_done: 525
# Log records from the iteration 525:
# 	 cost: 1.33013939857
# 	 epoch_took: 0.00302290916443
# 	 iteration_took: 0.000135898590088
# 	 test_cost: 22.4839687347
# 	 total_took: 1.07372999191
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 106
# 	 iterations_done: 530
# Log records from the iteration 530:
# 	 cost: 1.31388127804
# 	 epoch_took: 0.0028600692749
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 22.0714855194
# 	 total_took: 1.07936310768
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 107
# 	 iterations_done: 535
# Log records from the iteration 535:
# 	 cost: 1.28097629547
# 	 epoch_took: 0.00284194946289
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 21.6912326813
# 	 total_took: 1.08511996269
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 108
# 	 iterations_done: 540
# Log records from the iteration 540:
# 	 cost: 1.21776580811
# 	 epoch_took: 0.00277996063232
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 21.3297080994
# 	 total_took: 1.09081506729
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 109
# 	 iterations_done: 545
# Log records from the iteration 545:
# 	 cost: 1.13351988792
# 	 epoch_took: 0.00297808647156
# 	 iteration_took: 0.000134944915771
# 	 test_cost: 20.9625549316
# 	 total_took: 1.09679389
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 110
# 	 iterations_done: 550
# Log records from the iteration 550:
# 	 cost: 1.13561666012
# 	 epoch_took: 0.00382304191589
# 	 iteration_took: 0.00029182434082
# 	 test_cost: 20.5899105072
# 	 total_took: 1.10336995125
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 111
# 	 iterations_done: 555
# Log records from the iteration 555:
# 	 cost: 1.41239666939
# 	 epoch_took: 0.00283813476562
# 	 iteration_took: 0.000131845474243
# 	 test_cost: 20.2946052551
# 	 total_took: 1.10976099968
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 112
# 	 iterations_done: 560
# Log records from the iteration 560:
# 	 cost: 2.04141879082
# 	 epoch_took: 0.00279498100281
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 19.9222640991
# 	 total_took: 1.11527299881
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 113
# 	 iterations_done: 565
# Log records from the iteration 565:
# 	 cost: 6.50436639786
# 	 epoch_took: 0.00277495384216
# 	 iteration_took: 0.000130891799927
# 	 test_cost: 19.3805904388
# 	 total_took: 1.12078404427
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# ...
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 163
# 	 iterations_done: 815
# Log records from the iteration 815:
# 	 cost: 4.84221887589
# 	 epoch_took: 0.00278091430664
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 39.9795417786
# 	 total_took: 1.4144089222
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 164
# 	 iterations_done: 820
# Log records from the iteration 820:
# 	 cost: 4.58051156998
# 	 epoch_took: 0.00306797027588
# 	 iteration_took: 0.000134944915771
# 	 test_cost: 38.4885482788
# 	 total_took: 1.4202029705
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 165
# 	 iterations_done: 825
# Log records from the iteration 825:
# 	 cost: 4.36240339279
# 	 epoch_took: 0.00289511680603
# 	 iteration_took: 0.000135898590088
# 	 test_cost: 37.1910362244
# 	 total_took: 1.42583394051
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 166
# 	 iterations_done: 830
# Log records from the iteration 830:
# 	 cost: 4.17534399033
# 	 epoch_took: 0.00277209281921
# 	 iteration_took: 0.000131130218506
# 	 test_cost: 35.9602775574
# 	 total_took: 1.43127799034
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 167
# 	 iterations_done: 835
# Log records from the iteration 835:
# 	 cost: 4.13920879364
# 	 epoch_took: 0.00276184082031
# 	 iteration_took: 0.000130176544189
# 	 test_cost: 35.0676765442
# 	 total_took: 1.43692398071
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 168
# 	 iterations_done: 840
# Log records from the iteration 840:
# 	 cost: 3.91320562363
# 	 epoch_took: 0.00295901298523
# 	 iteration_took: 0.00012993812561
# 	 test_cost: 34.0247001648
# 	 total_took: 1.44298195839
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 169
# 	 iterations_done: 845
# Log records from the iteration 845:
# 	 cost: 3.99818658829
# 	 epoch_took: 0.00293779373169
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 33.3640670776
# 	 total_took: 1.44862389565
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 170
# 	 iterations_done: 850
# Log records from the iteration 850:
# 	 cost: 3.78296327591
# 	 epoch_took: 0.00284099578857
# 	 iteration_took: 0.000133991241455
# 	 test_cost: 32.7326202393
# 	 total_took: 1.45441389084
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 171
# 	 iterations_done: 855
# Log records from the iteration 855:
# 	 cost: 3.44264531136
# 	 epoch_took: 0.00439310073853
# 	 iteration_took: 0.000253915786743
# 	 test_cost: 32.033531189
# 	 total_took: 1.46151804924
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 172
# 	 iterations_done: 860
# Log records from the iteration 860:
# 	 cost: 3.13414144516
# 	 epoch_took: 0.00287413597107
# 	 iteration_took: 0.000128984451294
# 	 test_cost: 30.9893436432
# 	 total_took: 1.46743893623
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 173
# 	 iterations_done: 865
# Log records from the iteration 865:
# 	 cost: 4.07938528061
# 	 epoch_took: 0.00290012359619
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 30.0076293945
# 	 total_took: 1.4730489254
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 174
# 	 iterations_done: 870
# Log records from the iteration 870:
# 	 cost: 3.91086888313
# 	 epoch_took: 0.0029628276825
# 	 iteration_took: 0.000132083892822
# 	 test_cost: 29.8018741608
# 	 total_took: 1.47884392738
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 175
# 	 iterations_done: 875
# Log records from the iteration 875:
# 	 cost: 3.75860905647
# 	 epoch_took: 0.00284695625305
# 	 iteration_took: 0.000128984451294
# 	 test_cost: 29.5861206055
# 	 total_took: 1.4845020771
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 176
# 	 iterations_done: 880
# Log records from the iteration 880:
# 	 cost: 3.46107554436
# 	 epoch_took: 0.00290012359619
# 	 iteration_took: 0.000128984451294
# 	 test_cost: 29.253692627
# 	 total_took: 1.49008011818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 177
# 	 iterations_done: 885
# Log records from the iteration 885:
# 	 cost: 3.22116327286
# 	 epoch_took: 0.00294589996338
# 	 iteration_took: 0.0001380443573
# 	 test_cost: 28.4251346588
# 	 total_took: 1.4961309433
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 178
# 	 iterations_done: 890
# Log records from the iteration 890:
# 	 cost: 3.72951197624
# 	 epoch_took: 0.0028030872345
# 	 iteration_took: 0.000131130218506
# 	 test_cost: 28.3430519104
# 	 total_took: 1.50167894363
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 179
# 	 iterations_done: 895
# Log records from the iteration 895:
# 	 cost: 4.1851439476
# 	 epoch_took: 0.00279903411865
# 	 iteration_took: 0.000130176544189
# 	 test_cost: 27.6177463531
# 	 total_took: 1.50729489326
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 180
# 	 iterations_done: 900
# Log records from the iteration 900:
# 	 cost: 3.67728948593
# 	 epoch_took: 0.00307106971741
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 26.9023990631
# 	 total_took: 1.51308012009
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 181
# 	 iterations_done: 905
# Log records from the iteration 905:
# 	 cost: 3.84846305847
# 	 epoch_took: 0.00367212295532
# 	 iteration_took: 0.00025200843811
# 	 test_cost: 26.9993095398
# 	 total_took: 1.519520998
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 182
# 	 iterations_done: 910
# Log records from the iteration 910:
# 	 cost: 3.69172716141
# 	 epoch_took: 0.00298094749451
# 	 iteration_took: 0.000136852264404
# 	 test_cost: 27.0570678711
# 	 total_took: 1.52625703812
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 183
# 	 iterations_done: 915
# Log records from the iteration 915:
# 	 cost: 3.37023854256
# 	 epoch_took: 0.00279998779297
# 	 iteration_took: 0.000130891799927
# 	 test_cost: 26.9802856445
# 	 total_took: 1.5317530632
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 184
# 	 iterations_done: 920
# Log records from the iteration 920:
# 	 cost: 2.80717396736
# 	 epoch_took: 0.00278902053833
# 	 iteration_took: 0.00012993812561
# 	 test_cost: 26.3122196198
# 	 total_took: 1.53754711151
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 185
# 	 iterations_done: 925
# Log records from the iteration 925:
# 	 cost: 3.69057703018
# 	 epoch_took: 0.00295495986938
# 	 iteration_took: 0.000133037567139
# 	 test_cost: 26.4348640442
# 	 total_took: 1.54338097572
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 186
# 	 iterations_done: 930
# Log records from the iteration 930:
# 	 cost: 3.4012503624
# 	 epoch_took: 0.00294709205627
# 	 iteration_took: 0.000171899795532
# 	 test_cost: 26.4579429626
# 	 total_took: 1.54948210716
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 187
# 	 iterations_done: 935
# Log records from the iteration 935:
# 	 cost: 2.75038528442
# 	 epoch_took: 0.00280094146729
# 	 iteration_took: 0.000131130218506
# 	 test_cost: 25.8237762451
# 	 total_took: 1.55507993698
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 188
# 	 iterations_done: 940
# Log records from the iteration 940:
# 	 cost: 3.67600250244
# 	 epoch_took: 0.00277781486511
# 	 iteration_took: 0.000128984451294
# 	 test_cost: 25.9886054993
# 	 total_took: 1.56061911583
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 189
# 	 iterations_done: 945
# Log records from the iteration 945:
# 	 cost: 3.44336009026
# 	 epoch_took: 0.00290393829346
# 	 iteration_took: 0.000143051147461
# 	 test_cost: 26.0910701752
# 	 total_took: 1.56620788574
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 190
# 	 iterations_done: 950
# Log records from the iteration 950:
# 	 cost: 3.93764233589
# 	 epoch_took: 0.00291585922241
# 	 iteration_took: 0.0001380443573
# 	 test_cost: 25.5469779968
# 	 total_took: 1.57178497314
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 191
# 	 iterations_done: 955
# Log records from the iteration 955:
# 	 cost: 3.14485359192
# 	 epoch_took: 0.00283002853394
# 	 iteration_took: 0.000136137008667
# 	 test_cost: 24.8608665466
# 	 total_took: 1.57737994194
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 192
# 	 iterations_done: 960
# Log records from the iteration 960:
# 	 cost: 5.46024465561
# 	 epoch_took: 0.00292491912842
# 	 iteration_took: 0.00013279914856
# 	 test_cost: 23.9579467773
# 	 total_took: 1.58327102661
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 193
# 	 iterations_done: 965
# Log records from the iteration 965:
# 	 cost: 9.78784179688
# 	 epoch_took: 0.00377011299133
# 	 iteration_took: 0.0001380443573
# 	 test_cost: 54.5653190613
# 	 total_took: 1.59046602249
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 194
# 	 iterations_done: 970
# Log records from the iteration 970:
# 	 cost: 7.76358556747
# 	 epoch_took: 0.00289487838745
# 	 iteration_took: 0.000136137008667
# 	 test_cost: 51.5560073853
# 	 total_took: 1.59613895416
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 195
# 	 iterations_done: 975
# Log records from the iteration 975:
# 	 cost: 6.93761444092
# 	 epoch_took: 0.00287294387817
# 	 iteration_took: 0.000149011611938
# 	 test_cost: 48.8631820679
# 	 total_took: 1.60220193863
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 196
# 	 iterations_done: 980
# Log records from the iteration 980:
# 	 cost: 6.23494434357
# 	 epoch_took: 0.00283908843994
# 	 iteration_took: 0.000131130218506
# 	 test_cost: 46.4547348022
# 	 total_took: 1.60814595222
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 197
# 	 iterations_done: 985
# Log records from the iteration 985:
# 	 cost: 5.63120269775
# 	 epoch_took: 0.00285601615906
# 	 iteration_took: 0.000128984451294
# 	 test_cost: 44.2935943604
# 	 total_took: 1.61373209953
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 198
# 	 iterations_done: 990
# Log records from the iteration 990:
# 	 cost: 5.09241247177
# 	 epoch_took: 0.00279808044434
# 	 iteration_took: 0.00012993812561
# 	 test_cost: 42.3348503113
# 	 total_took: 1.61930704117
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 199
# 	 iterations_done: 995
# Log records from the iteration 995:
# 	 cost: 4.58921337128
# 	 epoch_took: 0.00276899337769
# 	 iteration_took: 0.000130891799927
# 	 test_cost: 40.5135574341
# 	 total_took: 1.62485003471
# -------------------------------------------------------------------------------
# TRAINING HAS BEEN FINISHED:
# -------------------------------------------------------------------------------
# Training status:
# 	 epochs_done: 199
# 	 iterations_done: 1000
# Log records from the iteration 1000:
# 	 final_total_took: 1.63046908379
# 	 iteration_took: 0.000133991241455
# 	 saved_to: sqrt
# 	 total_took: 1.63042497635
# 	 training_finish_requested: True
# 	 training_finished: True
